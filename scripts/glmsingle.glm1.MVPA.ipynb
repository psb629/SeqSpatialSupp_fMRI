# %%
import sys
import platform
from os.path import join, exists, abspath, dirname
from os import getcwd, makedirs
from glob import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colormaps, cm, colors
import matplotlib.patches as patches
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset
import scipy
from scipy.stats import ttest_1samp, ttest_rel
import seaborn as sns

from tqdm import tqdm

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GroupKFold, cross_val_score

# %%
import nibabel as nb
from nilearn import plotting, image
from nilearn.maskers import NiftiLabelsMasker
from nilearn.decoding import Decoder
from nipype.interfaces import fsl

# %%
import subprocess
import warnings

# %%
from IPython.display import Image, display

# %%
dir_current = getcwd().replace('\\','/')

tmp = dir_current.split('/')
idx = [ii for ii, s in enumerate(tmp) if s=='github'][0]

dir_git = '/'.join(tmp[:idx+1])
dir_git
# Out:
# '/Users/sungbeenpark/github'

# %%
dname = join(dir_git,'nitools')
sys.path.append(dname)
import nitools as nt

# %%
dname = join(dir_git,'SUITPy')
sys.path.append(dname)
import SUITPy as suit

# %%
dname = join(dir_git)
sys.path.append(dname)
import surfAnalysisPy as surf

# %%
dname = join(dir_git,'SeqSpatialSupp_fMRI')
sys.path.append(dname)
from SSS import deal_spm
from SSS import util as su
from SSS import stat as sstat
from SSS import plot as splt
from SSS import image as simage
from SSS import glmsingle as ssingle

# %% [markdown]
# ---

# %%
dir_root = su.get_dir_root()
dir_root
# Out:
# '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI'

# %%
list_sn = su.get_list_sn()

# %% [markdown]
# ---

# %%
glm = 1
dir_glm = ssingle.get_dir_glmsingle(glm)

# %%
dir_surf = join(ssingle.get_dir_glmsingle(),'surfaceWB')
dir_surf
# Out:
# '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/GLMsingle/surfaceWB'

# %%
dir_group = join(dir_surf,'group')

# %% [markdown]
# ---

# %%
dir_fs = su.get_dir_fs()
dir_roi = su.get_dir_roi()

# %%
hem = 'L'
border, brdr = simage.get_border(dir_git=dir_git, atlas='sulcus')
# border, brdr = simage.get_border(dir_git=dir_git, atlas='Glasser')

# %% [markdown]
# ---

# %%
fname = join(dir_roi,'SPark2025.32k.L.label.gii')
gii = nb.load(fname)
mask = gii.darrays[0].data

# %%
list_roi = []
for ii, label in enumerate(gii.labeltable.labels):
    if ii>0:
        list_roi.append(label.label)
list_roi = np.array(list_roi)
list_roi
# Out:
# array(['S1', 'M1', 'SMA', 'PMd', 'PMv', 'SPLa', 'SPLp', 'IPS', 'V4d',
#        'Vf', 'Vd', 'Vv', 'POS', 'TPOJ'], dtype='<U4')

# %%
g = surf.plot.plotmap(
    data=mask,
    surf='fs32k_%s'%hem,
    alpha=0.7,
    cmap=cm.jet_r.resampled(len(np.unique(mask))),
    # colorbar=True,
    # cscale=[-1,7],
    # threshold=[-thresh,thresh],
    borders=border, bordercolor='black', bordersize=1,
    overlay_type='func', render='matplotlib',
)
g.text(x=20, y=220, s=fname, ha='center', va='center', fontsize=10)
for line, (x, y) in brdr.items():
    g.text(x=x, y=y, s=line, ha='left', va='bottom', color='black', fontsize=10)

# %% [markdown]
# ---
# ---

# %%
def extract_data(data, mask, list_roi):
    result = {}
    for ii, roi in enumerate(list_roi):
        assert data.shape[-1] == mask.shape[0]
        val = ii+1
        idx = mask==val

        result[roi] = data[:,idx]

    return result

# %%
dir_work = join(dir_surf,'glm_%1d'%glm)
dir_work
# Out:
# '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/GLMsingle/surfaceWB/glm_1'

# %%
for shuffle in [True, False]:
    lines = {'subj':[], 'roi':[], 'score':[], 'shuffled':[]}
    for ii, sn in enumerate(tqdm(list_sn)):
        subj = 'S'+sn
    
        ## labels
        reginfo = deal_spm.load_reginfo(subj, dir_glm)
        # y = reginfo.name.values
        y = [reg[1] for reg in reginfo.name.values]
        if shuffle:
            np.random.shuffle(y)
        group = reginfo.run.values
    
        ## beta
        fname = join(dir_work,subj,'%s.%s.glm_%1d.beta.dscalar.nii'%(subj,hem,glm))
        cii = nb.load(fname)
        data = cii.get_fdata()
        dataset = extract_data(data, mask, list_roi)
    
        for roi, beta in dataset.items():
            ## pipeline: scaling + SVM
            clf = make_pipeline(
                SimpleImputer(strategy='constant', fill_value=0, keep_empty_features=True),
                StandardScaler(),
                SVC(kernel='linear', C=1)
            )
            ## group fold
            gkf = GroupKFold(n_splits=len(np.unique(group)))
    
            ## run cross-validation
            scores = cross_val_score(estimator=clf, X=beta, y=y, cv=gkf, groups=group)
            
            ## restore the result
            lines['subj'].append(subj)
            lines['roi'].append(roi)
            lines['score'].append(np.mean(scores))
            lines['shuffled'].append(shuffle)
        
    if not shuffle:
        df = pd.DataFrame(lines)
    else:
        dg = pd.DataFrame(lines)
# Out:
# ...
# 100%|███████████████████████████████████████████| 12/12 [03:02<00:00, 15.17s/it]

# %%
# chance distribution 예시
chance_mean = dg.groupby(['roi']).mean('score').score.mean()
chance_sem  = dg.groupby(['roi'])['score'].apply('sem').mean()

# %%
g = sns.barplot(
    data=df,
    x='roi', y='score', hue='roi',
    errorbar='se', capsize=0.2
)
g.axhline(y=chance_mean+chance_sem, linestyle='--', color='gray', alpha=1)
g.axhline(y=chance_mean-chance_sem, linestyle='--', color='gray', alpha=1)

for ii, roi in enumerate(list_roi):
    x = ii
    a = df[df.roi==roi].score.astype(float)
    b = dg[dg.roi==roi].score.astype(float)
    res = ttest_rel(a, b)
    pval = res.pvalue
    if pval < 0.05:
        print(roi, 't(%d)=%.4f, p=%.3e(%s)'%(res.df,res.statistic,pval,sstat.convert_pval_to_star(pval)))
        y = a.mean()+a.sem()
        g.text(
            x=x, y=y,
            s=sstat.convert_pval_to_star(pval), fontsize=10,
            ha='center', va='bottom'
        )
# Out:
# S1 t(11)=4.1723, p=1.557e-03(**)
# M1 t(11)=3.2634, p=7.553e-03(**)
# SMA t(11)=3.1067, p=9.985e-03(**)
# PMd t(11)=4.6634, p=6.899e-04(***)
# PMv t(11)=5.8787, p=1.064e-04(***)
# SPLa t(11)=5.5042, p=1.851e-04(***)
# IPS t(11)=2.6860, p=2.118e-02(*)
# V4d t(11)=3.8610, p=2.649e-03(**)
# Vf t(11)=2.9252, p=1.381e-02(*)
# Vd t(11)=6.6346, p=3.687e-05(****)
# Vv t(11)=6.5041, p=4.403e-05(****)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## MVPA

# %%
def fast_masking(img_data, img_mask, roi):
    if isinstance(img_data,str):
        img_data = nb.load(img_data)
    img_data = img_data.get_fdata()

    if isinstance(img_mask,str):
        img_mask = nb.load(img_mask)
    img_mask = img_mask.get_fdata().astype(int)
    assert img_data.shape[:3] == img_mask.shape
    
    list_roi_ = np.array(list_roi)
    idx = int(np.where(list_roi_==roi)[0][0])
    assert isinstance(idx, int)
    
    idx_mask = img_mask==idx+1
    data = img_data[idx_mask].T
    
    return data

# %%
shuffle = True

# %%
lines = {'subj':[], 'roi':[], 'score':[]}

for ii, sn in enumerate(tqdm(list_sn)):
    subj = 'S'+sn

    ## labels
    reginfo = deal_spm.load_reginfo(subj, dir_glm)
    y = reginfo.name.values
    y = np.array(['spatial' if 'S' in cue else ('letter' if 'L' in cue else 'invalid') for cue in y])
    if shuffle:
        np.random.shuffle(y)
    group = reginfo.run.values

    ## beta
    list_img_data = sorted(glob(join(dir_glm,subj,'beta_*.nii')))

    ## mask
    dir_roi = join(dir_fs, subj, 'mri')
    img_mask = image.resample_to_img(
        source_img=join(dir_roi,'lh.benson14_varea.vol.nii'),
        target_img=list_img_data[0],
        interpolation='nearest',
        force_resample=True,
        copy_header=True
    )
    
    ## get masked beta
    for roi in list_roi:
        dataset = []
        for img_data in list_img_data:
            data = fast_masking(img_data, img_mask, roi)
            dataset.append(data)
        dataset = np.array(dataset)

        ## pipeline: scaling + SVM
        clf = make_pipeline(
            SimpleImputer(strategy='constant', fill_value=0, keep_empty_features=True),
            StandardScaler(),
            SVC(kernel='linear', C=1)
        )

        ## group fold
        gkf = GroupKFold(n_splits=len(np.unique(group)))

        ## run cross-validation
        scores = cross_val_score(estimator=clf, X=dataset, y=y, cv=gkf, groups=group)
        
        ## restore the result
        lines['subj'].append(subj)
        lines['roi'].append(roi)
        lines['score'].append(np.mean(scores))

df = pd.DataFrame(lines)
if shuffle:
    fname = join(dir_group, 'df.glm_%1d.MVPA.shuffled.csv'%glm)
else:
    fname = join(dir_group, 'df.glm_%1d.MVPA.csv'%glm)
df.to_csv(fname, index=False)
del lines
# Out:
# 100%|████████████████████████████████████████| 12/12 [1:23:38<00:00, 418.21s/it]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Load the result

# %%
shuffle = True

# %%
fname = join(dir_group, 'df.glm_%1d.MVPA.shuffled.csv'%glm)
df_shuf = pd.read_csv(fname, header=0)
fname = join(dir_group, 'df.glm_%1d.MVPA.csv'%glm)
df = pd.read_csv(fname, header=0)

# %%
df_shuf
# Out:
#     subj  roi     score
# 0    S01   V1  0.512868
# 1    S01   V2  0.523897
# 2    S01   V3  0.531250
# 3    S01  hV4  0.509191
# 4    S01  VO1  0.529412
# ..   ...  ...       ...
# 139  S14  LO2  0.496324
# 140  S14  TO1  0.549632
# 141  S14  TO2  0.514706
# 142  S14  V3b  0.483456
# 143  S14  V3a  0.487132
#
# [144 rows x 3 columns]

# %%
df
# Out:
#     subj  roi     score
# 0    S01   V1  0.979779
# 1    S01   V2  0.988971
# 2    S01   V3  0.992647
# 3    S01  hV4  0.979779
# 4    S01  VO1  0.898897
# ..   ...  ...       ...
# 139  S14  LO2  0.851103
# 140  S14  TO1  0.840074
# 141  S14  TO2  0.669118
# 142  S14  V3b  0.805147
# 143  S14  V3a  0.897059
#
# [144 rows x 3 columns]

# %%
# chance distribution 예시
chance_mean = df_shuf.groupby(['roi']).mean('score').score
chance_std  = df_shuf.groupby(['roi'])['score'].apply('sem')

# %%
g = sns.barplot(
    data=df,
    x='roi', y='score', hue='roi',
    errorbar='sd', capsize=0.2
)
g.text(x=0., y=0.43, s='chance level', fontsize=10, ha='left')
g.axhline(y=1, linestyle='--', color='black', alpha=0.5)
g.grid(axis='both')
g.set_xlabel('')
g.set_ylabel('Decoding Accuracy', fontsize=14)
g.set_title('Decoding accuracy for the combined-cue in visual areas', fontsize=12)

## chance level
# g.axhline(y=0.5, linestyle='--', color='black', alpha=0.8)
y = chance_mean.mean()
dy = chance_std.mean()
g.axhline(y=y+dy, linestyle='--', color='black', alpha=0.8)
g.axhline(y=y-dy, linestyle='--', color='black', alpha=0.8)

## one sample t-test
dy = np.diff(g.get_ylim())*0.025

for ii, roi in enumerate(list_roi):
    # x = ii
    # dx = 0.4
    # y = chance_mean.loc[roi]
    # dy = chance_std.loc[roi]
    # g.plot([x-dx,x+dx], [y-dy, y-dy],'-', linewidth=2., color='black', alpha=0.4)
    # g.plot([x-dx,x+dx], [y+dy, y+dy],'-', linewidth=2., color='black', alpha=0.4)
    a = df[df.roi==roi].score.astype(float)
    b = df_shuf[df_shuf.roi==roi].score.astype(float)
    res = ttest_rel(a, b)
    if res.pvalue < 0.05:
        print(roi, 't(%d)=%.4f, p=%.3e(%s)'%(res.df,res.statistic,res.pvalue,sstat.convert_pval_to_star(res.pvalue)))
        x = ii
        y = a.mean()+a.std()
        g.text(
            x=x, y=y,
            s=sstat.convert_pval_to_star(res.pvalue), fontsize=10,
            ha='center', va='bottom'
        )
# Out:
# V1 t(11)=47.1701, p=4.763e-14(****)
# V2 t(11)=34.9434, p=1.265e-12(****)
# V3 t(11)=60.2192, p=3.276e-15(****)
# hV4 t(11)=54.0771, p=1.066e-14(****)
# VO1 t(11)=16.3290, p=4.649e-09(****)
# VO2 t(11)=6.4250, p=4.908e-05(****)
# LO1 t(11)=13.2341, p=4.227e-08(****)
# LO2 t(11)=12.1943, p=9.861e-08(****)
# TO1 t(11)=8.1373, p=5.555e-06(****)
# TO2 t(11)=6.1715, p=6.992e-05(****)
# V3b t(11)=11.4254, p=1.923e-07(****)
# V3a t(11)=23.7275, p=8.484e-11(****)

# %% [markdown]
# |Area|Name|Main Function|
# |-|-|-|
# |V1|Primary Visual Cortex|Initial processing of visual input; detects basic features like orientation, contrast, and edges. Responsible for spatial mapping and high acuity vision.|
# |V2|Secondary Visual Cortex|Integrates and processes V1 information; handles more complex features such as contours, binocular disparity, and figure-ground separation. Sends outputs to V3, V4, V5.|
# |V3|Third Visual Area|Interprets global motion and dynamic form, depth perception, and integrates complex patterns. Sometimes divided into dorsal and ventral parts with specialized roles.|
# |hV4|Human Visual Area 4|Specialized for color processing, intermediate complex shape recognition, and attention modulation.|
# |VO1|Ventral Occipital Area 1|Located just anterior to hV4, VO1 processes color and form information while strongly representing the peripheral visual field.|
# |VO2|Ventral Occipital Area 2|Positioned anterior to VO1, VO2 works with VO1 as part of the ventral occipital cluster, contributing to higher‑order visual processing and object recognition, and includes a foveal representation for central vision.|
# |LO1|Lateral Occipital Area 1|acts as a relatively stable retinotopic map, supporting early shape processing.|
# |LO2|Lateral Occipital Area 2|complements LO1 with a mirror-reversed map, more distorted retinotopy, and stronger involvement in integrating complex shape and motion cues.|
# |TO1|Temporal Occipital Area 1|Essential for motion detection and dynamic visual tracking, linked to the MT/V5 motion complex.|
# |TO2|Temporal Occipital Area 2|Supports TO1 by processing complex or predicted motions in moving objects.|
# |V3a|Visual Area 3a|Sensitive to motion, depth, and 3D structure; thought to aid in spatial perception and movement processing.|
# |V3b|Visual Area 3b|Involved in integration of motion and depth cues, especially for stereoscopic (3D) vision.|

# %%
display(Image(filename='../figures/LO1-2.jpg'))

# %%
display(Image(filename='../figures/VO_angle.jpg'))

# %%
display(Image(filename='../figures/VO_eccentricity.jpg'))

# %% [markdown]
# ---
