# %%
import sys
import platform
from os.path import join, exists, abspath, dirname
from os import getcwd, makedirs
from glob import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colormaps, cm, colors
import matplotlib.patches as patches
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset
import scipy
from sklearn.metrics import r2_score
import seaborn as sns

from tqdm import tqdm

# %%
import nibabel as nb
from nilearn import plotting, image
from nipype.interfaces import fsl

# %%
dir_current = getcwd().replace('\\','/')

tmp = dir_current.split('/')
idx = [ii for ii, s in enumerate(tmp) if s=='github'][0]

dir_git = '/'.join(tmp[:idx+1])
dir_git
# Out:
# '/home/sungbeenpark/github'

# %%
dname = join(dir_git,'nitools')
sys.path.append(dname)
import nitools as nt

# %%
dname = join(dir_git,'SUITPy')
sys.path.append(dname)
import SUITPy as suit

# %%
dname = join(dir_git)
sys.path.append(dname)
import surfAnalysisPy as surf

# %%
dname = join(dir_git,'SeqSpatialSupp_fMRI')
sys.path.append(dname)
from SSS import deal_spm
from SSS import util as su
from SSS import stat as sstat
from SSS import plot as splt
from SSS import image as simage
from SSS import glmsingle as ssingle

# %% [markdown]
# ---

# %%
glm = 1
dir_glm = su.get_dir_glm(glm)

# %%
list_sn = su.get_list_sn()

# %% [markdown]
# ---

# %%
dir_surf = join(su.get_dir_surf())
dir_surf
# Out:
# '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB'

# %%
list_roi = simage.get_list_roi()

# %%
border, brdr = simage.get_border(join(dir_git,'surfAnalysisPy'))
hem = 'L'

# %%
dir_group = join(dir_surf,'group')
exists(dir_group)
# Out:
# True

# %% [markdown]
# ---

# %%
subj = 'S01'

# %%
reginfo = deal_spm.load_reginfo(subj,dir_glm)
reginfo
# Out:
#     sn  run  cond  regIdx  seq cue    reg
# 0    1    1     1       1    1   L  (1,L)
# 1    1    1     2       2    1   S  (1,S)
# 2    1    1     3       3    2   L  (2,L)
# 3    1    1     4       4    2   S  (2,S)
# 4    1    1     5       5    3   L  (3,L)
# ..  ..  ...   ...     ...  ...  ..    ...
# 59   1    8     4      60    2   S  (2,S)
# 60   1    8     5      61    3   L  (3,L)
# 61   1    8     6      62    3   S  (3,S)
# 62   1    8     7      63    4   L  (4,L)
# 63   1    8     8      64    4   S  (4,S)
#
# [64 rows x 7 columns]

# %%
def get_df_idx(subj, glm):
    reginfo = deal_spm.load_reginfo(subj,dir_glm)
    df_idx = pd.DataFrame()
    df_idx['letter'] = reginfo.cue.str.contains('L', case=False).values
    df_idx['spatial'] = reginfo.cue.str.contains('S', case=False).values
    for seq in np.arange(1,5):
        df_idx['seq%d'%seq] = reginfo.seq.astype(str).str.contains('%d'%seq, case=False).values
    
    return df_idx

# %%
df_idx = get_df_idx(subj=subj, glm=glm)
df_idx
# Out:
#     letter  spatial   seq1   seq2   seq3   seq4
# 0     True    False   True  False  False  False
# 1    False     True   True  False  False  False
# 2     True    False  False   True  False  False
# 3    False     True  False   True  False  False
# 4     True    False  False  False   True  False
# ..     ...      ...    ...    ...    ...    ...
# 59   False     True  False   True  False  False
# 60    True    False  False  False   True  False
# 61   False     True  False  False   True  False
# 62    True    False  False  False  False   True
# 63   False     True  False  False  False   True
#
# [64 rows x 6 columns]

# %% [markdown]
# ### i) Calculate Contrast

# %%
dir_work = join(dir_surf,'glm_%1d'%glm)

# %%
dataset = {}
for ii, nn in enumerate(tqdm(list_sn)):
    subj = 'S'+nn

    ## ============ beta =========== ##
    ## index
    df_idx = get_df_idx(subj=subj, glm=glm)

    ## load ResMS
    fname = join(dir_work,subj,'%s.%s.glm_%d.ResMS.func.gii'%(subj,hem,glm))
    darray = nb.load(fname).darrays
    ResMS = darray[0].data
    
    ## load beta
    sss = 'beta_mean'
    fname = join(dir_work,subj,'%s.%s.glm_%d.beta.func.gii'%(subj,hem,glm))
    darrays = nb.load(fname).darrays
    data = np.ones((len(df_idx),32492)) * np.nan
    for jj, darray in enumerate(darrays):
        data[jj] = darray.data
    ## ============================= ##
    ## contrast
    for cue in ['letter','spatial']:
        if ii==0:
            dataset[cue] = np.ones((len(list_sn),32492)) * np.nan
        idx_cue = df_idx[cue].values.astype(int)
        ## cue
        contrast = idx_cue
        dataset[cue][ii,:] = contrast@data

    ## ============ spmT =========== ##
    # ## load spmT
    # sss = 'spmT'
    # fname = join(dir_work,subj,'%s.%s.glm_%d.t.func.gii'%(subj,hem,glm))
    # darrays = nb.load(fname).darrays
    # t_order = np.genfromtxt(
    #     join(dir_work,subj,'%s.t_orders.csv'%subj),
    #     delimiter='\t', dtype=None, encoding='utf-8'
    # )
    # data = np.ones((len(t_order),32492)) * np.nan
    # for jj, darray in enumerate(darrays):
    #     tmap = darray.data
    #     data[jj] = tmap

    # for jj, name in enumerate(t_order):
    #     cond = name.split('.')[0].replace('spmT_','').replace('_L','_letter').replace('_S','_spatial').replace('Letter','letter').replace('Spatial','spatial')
    #     if ii==0:
    #         dataset[cond] = np.ones((len(list_sn),32492))
    #     dataset[cond][ii,:] = data[jj]
    ## ============================= ##
# Out:
# 100%|███████████████████████████████████████████████████| 12/12 [00:26<00:00,  2.18s/it]

# %% [markdown]
# ### Save the dataset as cifti

# %%
dir_output = join(dir_surf,'glm_%1d'%glm)
for key, value in dataset.items():
    simage.save_surf2cifti(
        data=value,
        dir_output=dir_output,
        label_axis=['S'+sn for sn in list_sn],
        prefix='cifti.%s.glm_%1d.%s.%s'%(hem,glm,sss,key)
    )

# %% [markdown]
# ### ii) Load the dataset from cifti

# %%
sss = 'beta_mean'
dataset = {}
for cond in ['letter','spatial']:
    fname = join(dir_surf,'glm_%1d'%glm, 'smooth.cifti.%s.glm_%1d.%s.%s.dscalar.nii'%(hem,glm,sss,cond))
    dataset[cond] = nb.load(fname).get_fdata()

# %% [markdown]
# ### t-test

# %%
for key, value in dataset.items():
    data = np.ones((2,32492)) * np.nan
    ## coeffcient
    data[0] = np.mean(value, axis=0)
    ## t-stat
    res = scipy.stats.ttest_1samp(value, popmean=0, axis=0)
    thresh = sstat.convert_alpha_to_tval(alpha=0.05, df=res.df.mean())
    data[1] = res.statistic
    ## save the result as cifti
    simage.save_surf2cifti(
        data=data,
        dir_output=dir_group,
        label_axis=['coef','tstat'],
        prefix='cifti.%s.glm_%1d.t_stat.%s'%(hem,glm,key)
    )

# %% [markdown]
# ## 1. Letter vs. Spatial

# %%
dir_work = dir_group
glob(join(dir_work,'*.t_stat.*.nii'))
# Out:
# ['/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_1.t_stat.letter.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_1.t_stat.spatial.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.acRS_letter.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.acRS_spatial.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.B_letter.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.B_spatial.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.C_letter.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.C_spatial.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.N_letter.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.N_spatial.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.S_letter.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.S_spatial.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.wRS_letter.dscalar.nii',
#  '/mnt/f/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.wRS_spatial.dscalar.nii']

# %%
thresh = sstat.convert_alpha_to_tval(alpha=0.05, df=len(list_sn))
thresh
# Out:
# np.float64(2.1788128296634177)

# %%
cmap = cm.jet
cmap

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,5))

for ii, sss in enumerate(['letter','spatial']):
    ax=axs[ii]
    plt.sca(ax)
    fname = join(dir_group,'cifti.%s.glm_%1d.t_stat.%s.dscalar.nii'%(hem,glm,sss))
    data = np.array(nb.load(fname).get_fdata())

    color = 'black'
    g = surf.plot.plotmap(
        data=data[1],
        surf='fs32k_%s'%hem,
        alpha=0.7,
        cmap=cmap, colorbar=True,
        cscale=[-10,10],
        threshold=[-thresh,thresh],
        borders=border, bordercolor=color, bordersize=1,
        overlay_type='func', render='matplotlib',
    )
    g.text(x=20, y=220, s=sss, ha='center', va='center', fontsize=14)
    for line, (x, y) in brdr.items():
        g.text(x=x, y=y, s=line, ha='left', va='bottom', color=color, fontsize=9)

# %% [markdown]
# ## 2. Zoom-in

# %%
# vmin, vmax = -10, 10

# %%
# fig, axs = plt.subplots(ncols=2, figsize=(12,5))

# for ii, sss in enumerate(['letter','spatial']):
#     ax = axs[ii]
#     plt.sca(ax)
    
#     result = scipy.stats.ttest_1samp(dataset[sss], popmean=0, axis=0)
#     thresh = sstat.convert_alpha_to_tval(alpha=0.01, df=result.df.mean())

#     data = np.copy(result.statistic)
#     # data = scipy.ndimage.gaussian_filter(data, sigma=0.75)
#     data[np.abs(result.statistic)<thresh] = np.nan
#     if sss=='letter':
#         cmap = cm.seismic
#     else:
#         cmap = cm.seismic_r
#     color = 'white'
#     g = surf.plot.plotmap(
#         data=data,
#         surf='fs32k_L',
#         alpha=0.7,
#         cmap=cmap, colorbar=True,
#         cscale=[vmin,vmax],
#         borders=border, bordercolor=color, bordersize=1,
#         overlay_type='func', render='matplotlib'
#     )
#     g.text(x=20, y=220, s=sss, ha='center', va='center', fontsize=14)
#     for line, (x, y) in brdr.items():
#         g.text(x=x, y=y, s=line, ha='left', va='bottom', color=color, fontsize=9)
        
#     rect = patches.Rectangle(
#         xy=(-40, -40), width=260, height=170,
#         linewidth=2, edgecolor='k', facecolor='none', linestyle='--'
#     )
#     g.add_patch(rect)
#     # xmin = rect.get_x()
#     # xmax = xmin + rect.get_width()
#     # ymin = rect.get_y()
#     # ymax = ymin + rect.get_height()
#     # g.set_xlim(xmin,xmax)
#     # g.set_ylim(ymin,ymax)

# %% [markdown]
# ## 3. Overlap t-map

# %%
dataset = []
threshold = np.ones(3)

for ii, sss in enumerate(['letter',None,'spatial']):
    if sss==None:
        dataset.append(sss)
        continue
    ## set alpha
    thresh = sstat.convert_alpha_to_tval(alpha=0.01, df=len(list_sn)-1)
    threshold[ii] = thresh

    ## set rgb
    fname = join(dir_group,'cifti.%s.glm_%1d.t_stat.%s.dscalar.nii'%(hem,glm,sss))
    data = np.array(nb.load(fname).get_fdata())
    dataset.append(data[1])

# %%
color = 'white'
g = surf.plot.plotmap(
    data=suit.flatmap.map_to_rgb(data=dataset, threshold=threshold),
    surf='fs32k_%s'%hem,
    colorbar=True,
    borders=border, bordercolor=color, bordersize=1,
    overlay_type='rgb',
)
g.text(x=20, y=220, s='overlap', ha='center', va='center', fontsize=14)
for line, (x, y) in brdr.items():
    g.text(x=x, y=y, s=line, ha='left', va='bottom', color=color, fontsize=9)
