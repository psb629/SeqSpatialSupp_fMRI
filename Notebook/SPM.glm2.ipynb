# %%
import sys
import platform
from os.path import join, exists, abspath, dirname
from os import getcwd, makedirs
from glob import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colormaps, cm, colors
import scipy
from sklearn.metrics import r2_score
import seaborn as sns

from tqdm import tqdm

# %%
import nibabel as nb
from nilearn import plotting, image
from nilearn.glm.contrasts import compute_contrast
from nipype.interfaces import fsl

# %%
dir_current = getcwd().replace('\\','/')

tmp = dir_current.split('/')
idx = [ii for ii, s in enumerate(tmp) if s=='github'][0]

dir_git = '/'.join(tmp[:idx+1])
dir_git
# Out:
# '/Users/sungbeenpark/github'

# %%
dname = join(dir_git,'nitools')
sys.path.append(dname)
import nitools as nt

# %%
dname = join(dir_git,'SUITPy')
sys.path.append(dname)
import SUITPy as suit

# %%
dname = join(dir_git)
sys.path.append(dname)
import surfAnalysisPy as surf

# %%
dname = join(dir_git,'SeqSpatialSupp_fMRI')
sys.path.append(dname)
from SSS import deal_spm
from SSS import util as su
from SSS import stat as sstat
from SSS import plot as splt
from SSS import image as simage
from SSS import glmsingle as ssingle

# %% [markdown]
# ---

# %%
list_sn = su.get_list_sn()
list_roi = simage.get_list_roi()
list_run = su.get_list_run()

# %% [markdown]
# ---

# %%
border, brdr = simage.get_border(dir_git=dir_git, atlas='sulcus')
# border, brdr = simage.get_border(dir_git=dir_git, atlas='Glasser')
hem = 'L'

# %% [markdown]
# ---

# %%
glm = 2
dir_glm = join(su.get_dir_glm(glm))

# %%
dir_surf = join(su.get_dir_surf())
dir_surf
# Out:
# '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB'

# %%
dir_group = join(dir_surf,'group')

# %% [markdown]
# ---
# ---

# %%
subj = 'S01'

# %%
reginfo = deal_spm.load_reginfo(subj,dir_glm)
reginfo
# Out:
#     sn  run  cond  regIdx   reg
# 0    1    1     1       1  B_L
# 1    1    1     2       2  B_S
# 2    1    1     3       3  C_L
# 3    1    1     4       4  C_S
# 4    1    1     5       5  N_L
# ..  ..  ...   ...     ...   ...
# 67   1    8     5      68  N_L
# 68   1    8     6      69  N_S
# 69   1    8     7      70  Rest
# 70   1    8     8      71  S_L
# 71   1    8     9      72  S_S
#
# [72 rows x 5 columns]

# %%
# SPM = deal_spm.load_SPM(SPM=join(dir_glm, subj,'SPM.mat'))
# design = SPM['xX/X'][:].T

# list_cond = reginfo.reg.unique()
# fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(4*4,4*2))
# axs = np.concatenate(axs)
# for rr, run in enumerate(list_run):
#     ax = axs[rr]
#     nTR = 407
#     ncond = len(list_cond)
#     idx_row = np.arange(nTR*rr,nTR*(rr+1))
#     idx_col = np.arange(ncond*rr,ncond*(rr+1))
#     X = design[idx_row][:,idx_col]
#     g = sns.heatmap(X, ax=ax)
#     g.set_title(run)
#     g.set_xticklabels(list_cond, rotation=40)

# %%
def get_df_idx(subj, glm):
    reginfo = deal_spm.load_reginfo(subj,dir_glm)
    df_idx = pd.DataFrame()
    df_idx['letter'] = np.array([True if '_L' in name else False for name in reginfo.reg])
    df_idx['spatial'] = np.array([True if '_S' in name else False for name in reginfo.reg])
    df_idx['B'] = np.array([True if 'B_' in name else False for name in reginfo.reg])
    df_idx['S'] = np.array([True if 'S_' in name else False for name in reginfo.reg])
    df_idx['C'] = np.array([True if 'C_' in name else False for name in reginfo.reg])
    df_idx['N'] = np.array([True if 'N_' in name else False for name in reginfo.reg])
    return df_idx

# %%
df_idx = get_df_idx(subj=subj, glm=glm)
df_idx
# Out:
#     letter  spatial      B      S      C      N
# 0     True    False   True  False  False  False
# 1    False     True   True  False  False  False
# 2     True    False  False  False   True  False
# 3    False     True  False  False   True  False
# 4     True    False  False  False  False   True
# ..     ...      ...    ...    ...    ...    ...
# 67    True    False  False  False  False   True
# 68   False     True  False  False  False   True
# 69   False    False  False  False  False  False
# 70    True    False  False   True  False  False
# 71   False     True  False   True  False  False
#
# [72 rows x 6 columns]

# %% [markdown]
# ---
# ---

# %%
# fname = join(dir_work,subj,'%s.%s.glm_%d.beta.func.gii'%(subj,hem,glm))
# darrays = nb.load(fname).darrays
# print(len(darrays))

# %%
# cmap = cm.seismic
# cmap = cm.jet
# cmap

# %%
# data = darrays[0].data
# data = scipy.ndimage.gaussian_filter(data, sigma=0.6)
# g = surf.plot.plotmap(
#     data=data,
#     surf='fs32k_%s'%hem,
#     alpha=0.7,
#     cmap=cmap, colorbar=True,
#     cscale=[-5,5],
#     threshold=[-2.,2.],
#     borders=border, bordercolor='black', bordersize=3,
#     overlay_type='func', render='matplotlib',
# )

# %% [markdown]
# ## i) Calculate Contrasts

# %%
dir_work = join(dir_surf,'glm_%1d'%glm)

# %%
dataset = {}
for ii, sn in enumerate(tqdm(list_sn)):
    subj = 'S'+sn
    
    ## ============ beta =========== ##
    ## index
    df_idx = get_df_idx(subj=subj, glm=glm)
    
    ## load ResMS
    fname = join(dir_work,subj,'%s.%s.glm_%d.ResMS.func.gii'%(subj,hem,glm))
    darray = nb.load(fname).darrays
    ResMS = darray[0].data
    
    ## load beta
    sss = 'beta_mean'
    fname = join(dir_work,subj,'%s.%s.glm_%d.beta.func.gii'%(subj,hem,glm))
    darrays = nb.load(fname).darrays
    data = np.ones((len(df_idx),32492)) * np.nan
    for jj, darray in enumerate(darrays):
        beta = darray.data
        # data[jj] = beta
        data[jj] = beta/(np.sqrt(ResMS)+1.e-14) # prewhitening
    ## ============================= ##
    ## contrast
    for cue in ['letter', 'spatial']:
        if ii==0:
            dataset['B_'+cue] = np.ones((len(list_sn),32492))
            dataset['S_'+cue] = np.ones((len(list_sn),32492))
            dataset['C_'+cue] = np.ones((len(list_sn),32492))
            dataset['N_'+cue] = np.ones((len(list_sn),32492))
            dataset['wRS_'+cue] = np.ones((len(list_sn),32492))
            dataset['acRS_'+cue] = np.ones((len(list_sn),32492))
        idx_B = ((df_idx[cue])&(df_idx.B)).values.astype(int)
        idx_S = ((df_idx[cue])&(df_idx.S)).values.astype(int)
        idx_C = ((df_idx[cue])&(df_idx.C)).values.astype(int)
        idx_N = ((df_idx[cue])&(df_idx.N)).values.astype(int)
        ## condition B
        contrast = idx_B
        dataset['B_'+cue][ii,:] = contrast@data
        ## condition S
        contrast = idx_S
        dataset['S_'+cue][ii,:] = contrast@data
        ## condition B
        contrast = idx_C
        dataset['C_'+cue][ii,:] = contrast@data
        ## condition N
        contrast = idx_N
        dataset['N_'+cue][ii,:] = contrast@data
        ## within cue
        contrast = idx_B - idx_S
        dataset['wRS_'+cue][ii,:] = contrast@data
        ## across cue
        contrast = idx_C - idx_N
        dataset['acRS_'+cue][ii,:] = contrast@data

    ## ============ spmT =========== ##
    # ## load spmT
    # sss = 'spmT'
    # fname = join(dir_work,subj,'%s.%s.glm_%d.t.func.gii'%(subj,hem,glm))
    # darrays = nb.load(fname).darrays
    # t_order = np.genfromtxt(
    #     join(dir_work,subj,'%s.t_orders.csv'%subj),
    #     delimiter='\t', dtype=None, encoding='utf-8'
    # )
    # data = np.ones((len(t_order),32492)) * np.nan
    # for jj, darray in enumerate(darrays):
    #     tmap = darray.data
    #     data[jj] = tmap

    # for jj, name in enumerate(t_order):
    #     cond = name.split('.')[0].replace('spmT_','').replace('_L','_letter').replace('_S','_spatial').replace('Letter','letter').replace('Spatial','spatial')
    #     if ii==0:
    #         dataset[cond] = np.ones((len(list_sn),32492))
    #     dataset[cond][ii,:] = data[jj]
    ## ============================= ##
# Out:
# 100%|███████████████████████████████████████████████████| 12/12 [00:30<00:00,  2.58s/it]

# %% [markdown]
# ### Save the dataset as cifti

# %%
dir_output = join(dir_surf,'glm_%1d'%glm)
for key, value in dataset.items():
    simage.save_surf2cifti(
        data=value,
        dir_output=dir_output,
        label_axis=['S'+sn for sn in list_sn],
        prefix='cifti.%s.glm_%1d.%s.%s'%(hem,glm,sss,key)
    )

# %% [markdown]
# ## ii) Load the dataset from cifti

# %%
dir_work = join(dir_surf,'glm_%1d'%glm)

# %%
dataset = {}
for c1 in ['B', 'S', 'C', 'N', 'wRS', 'acRS']:
    for c2 in ['letter','spatial']:
        cond = '%s_%s'%(c1,c2)
        fname = join(dir_work, 'smooth.cifti.%s.glm_%1d.beta_mean.%s.dscalar.nii'%(hem,glm,cond))
        dataset[cond] = nb.load(fname).get_fdata()

# %% [markdown]
# ### t-test

# %%
for key, value in dataset.items():
    data = np.ones((2,32492)) * np.nan
    ## coeffcient
    data[0] = np.mean(value, axis=0)
    ## t-stat
    res = scipy.stats.ttest_1samp(value, popmean=0, axis=0)
    thresh = sstat.convert_alpha_to_tval(alpha=0.05, df=res.df.mean())
    data[1] = res.statistic
    ## save the result as cifti
    simage.save_surf2cifti(
        data=data,
        dir_output=dir_group,
        label_axis=['coef','tstat'],
        prefix='cifti.%s.glm_%1d.t_stat.%s'%(hem,glm,key)
    )

# %% [markdown]
# ---
# ---

# %%
cmap = cm.seismic
cmap

# %%
dir_work = dir_group
glob(join(dir_work,'*.t_stat.*.nii'))
# Out:
# ['/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_1.t_stat.letter.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_1.t_stat.spatial.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.acRS_letter.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.acRS_spatial.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.B_letter.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.B_spatial.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.C_letter.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.C_spatial.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.N_letter.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.N_spatial.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.S_letter.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.S_spatial.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.wRS_letter.dscalar.nii',
#  '/Volumes/Diedrichsen_data$/data/SeqSpatialSupp_fMRI/surfaceWB/group/cifti.L.glm_2.t_stat.wRS_spatial.dscalar.nii']

# %% [markdown]
# ### Letter

# %%
thresh = sstat.convert_alpha_to_tval(alpha=0.05, df=len(list_sn)-1)

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(12,10))
axs = np.concatenate(axs)

cue = 'letter'
for ii, cc in enumerate(['B','S','C','N']):
    ax = axs[ii]
    plt.sca(ax)

    cond = cc+'_%s'%cue
    fname = join(dir_group,'cifti.%s.glm_%1d.t_stat.%s.dscalar.nii'%(hem,glm,cond))
    data = np.array(nb.load(fname).get_fdata())
    
    color = 'black'
    g = surf.plot.plotmap(
        data=data[1],
        surf='fs32k_%s'%hem,
        alpha=0.7,
        cmap=cmap, colorbar=True,
        cscale=[-20,20],
        threshold=[-thresh,thresh],
        borders=border, bordercolor=color, bordersize=1,
        overlay_type='func', render='matplotlib',
    )
    g.text(x=20, y=220, s=cond, ha='center', va='center', fontsize=14)
    for line, (x, y) in brdr.items():
        g.text(x=x, y=y, s=line, ha='left', va='bottom', color=color, fontsize=9)

# %% [markdown]
# ### Spatial

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(12,10))
axs = np.concatenate(axs)

cue = 'spatial'
for ii, cc in enumerate(['B','S','C','N']):
    ax = axs[ii]
    plt.sca(ax)
    
    cond = cc+'_%s'%cue
    fname = join(dir_group,'cifti.%s.glm_%1d.t_stat.%s.dscalar.nii'%(hem,glm,cond))
    data = np.array(nb.load(fname).get_fdata())
    
    color = 'black'
    g = surf.plot.plotmap(
        data=data[1],
        surf='fs32k_%s'%hem,
        alpha=0.7,
        cmap=cmap, colorbar=True,
        cscale=[-20,20],
        threshold=[-thresh,thresh],
        borders=border, bordercolor=color, bordersize=1,
        overlay_type='func', render='matplotlib',
    )
    g.text(x=20, y=220, s=cond, ha='center', va='center', fontsize=14)
    for line, (x, y) in brdr.items():
        g.text(x=x, y=y, s=line, ha='left', va='bottom', color=color, fontsize=9)

# %% [markdown]
# ### within Cue

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10,4))

for ii, sss in enumerate(['wRS_letter','wRS_spatial']):
    ax=axs[ii]
    plt.sca(ax)
    fname = join(dir_group,'cifti.%s.glm_%1d.t_stat.%s.dscalar.nii'%(hem,glm,sss))
    data = np.array(nb.load(fname).get_fdata())
    
    color = 'black'
    g = surf.plot.plotmap(
        data=data[1],
        surf='fs32k_%s'%hem,
        alpha=0.7,
        cmap=cmap, colorbar=True,
        cscale=[-5,5],
        threshold=[-thresh,thresh],
        borders=border, bordercolor='black', bordersize=1,
        overlay_type='func', render='matplotlib',
    )
    g.text(x=20, y=220, s=sss, ha='center', va='center', fontsize=14)
    for line, (x, y) in brdr.items():
        g.text(x=x, y=y, s=line, ha='left', va='bottom', color=color, fontsize=9)

# %%
# fig.savefig(
#     join(dir_result, 'wRS.png'),
#     dpi=300, facecolor=[1,1,1,1], bbox_inches = "tight"
# )

# %% [markdown]
# ### across Cue

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10,4))

for ii, sss in enumerate(['acRS_letter','acRS_spatial']):
    ax=axs[ii]
    plt.sca(ax)
    fname = join(dir_group,'cifti.%s.glm_%1d.t_stat.%s.dscalar.nii'%(hem,glm,sss))
    data = np.array(nb.load(fname).get_fdata())
    
    color = 'black'
    g = surf.plot.plotmap(
        data=data[1],
        surf='fs32k_%s'%hem,
        alpha=0.7,
        cmap=cmap, colorbar=True,
        cscale=[-5,5],
        threshold=[-thresh,thresh],
        borders=border, bordercolor='black', bordersize=1,
        overlay_type='func', render='matplotlib',
    )
    g.text(x=20, y=220, s=sss, ha='center', va='center', fontsize=14)
    for line, (x, y) in brdr.items():
        g.text(x=x, y=y, s=line, ha='left', va='bottom', color=color, fontsize=9)

# %%
# fig.savefig(
#     join(dir_result, 'acRS.png'),
#     dpi=300, facecolor=[1,1,1,1], bbox_inches = "tight"
# )

# %% [markdown]
# ---

# %% [markdown]
# ---
